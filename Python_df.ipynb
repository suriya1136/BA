# %%
import pandas as pd
import os

# %%
print(os.getcwd())  # Print the current working directory
# Out:
# c:\Users\SURIYA KUMAR\OneDrive\ML\Python A-Z\Section 5_ Data Frames

# %%
#specify the file path
#dont forget \\ to avoid escape characters
stats = pd.read_csv("C:\\Users\SURIYA KUMAR\OneDrive\ML\Python A-Z\Section 5_ Data Frames\S5-Demographic-Data.csv")

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#No. of rows
len(stats)
# Out:
# 195

# %%
#see columns
count = 0
for i in stats.columns:
    count += 1
print("Number of columns:", count)

# or

print(len(stats.columns))
stats.columns
# Out:
# Number of columns: 5
# 5
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#top rows
stats.head() #default 5 rows
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#bottom rows
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#information about the data
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#statistics of the data
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()  # Transpose the statistics for better readability
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
#changing headers
stats.columns = ['Country Name', 'Internet Users', 'Birth Rate', 'Death Rate', 'Population']
stats.head()  # Display the first few rows to see the updated headers
# Out:
#            Country Name Internet Users  Birth Rate  Death Rate  \
# 0                 Aruba            ABW      10.244        78.9
# 1           Afghanistan            AFG      35.253         5.9
# 2                Angola            AGO      45.985        19.1
# 3               Albania            ALB      12.877        57.2
# 4  United Arab Emirates            ARE      11.044        88.0
#
#             Population
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#resetting headers
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']
stats.head()  # Display the first few rows to see the updated headers
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#slcing the data
stats[5:10]  # Rows 5 to 9
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[::-1]  # Reverse the DataFrame
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats[::20] # Every 20th row
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
#column slicing
stats[['CountryName', 'InternetUsers']].head() # Display specific columns
# Out:
#             CountryName  InternetUsers
# 0                 Aruba           78.9
# 1           Afghanistan            5.9
# 2                Angola           19.1
# 3               Albania           57.2
# 4  United Arab Emirates           88.0

# %%
#Quick access
stats.CountryName.head()  # Access a specific column directly
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
#combining row and column slicing
stats[5:10][['CountryName', 'InternetUsers']]  # Rows 5 to 9 for specific columns
# Out:
#            CountryName  InternetUsers
# 5            Argentina        59.9000
# 6              Armenia        41.9000
# 7  Antigua and Barbuda        63.4000
# 8            Australia        83.0000
# 9              Austria        80.6188

# %%
#combining row and column slicing - method 2
df1 = stats[5:10]
df1[['CountryName', 'InternetUsers']]  # Display specific columns from the sliced DataFrame
# Out:
#            CountryName  InternetUsers
# 5            Argentina        59.9000
# 6              Armenia        41.9000
# 7  Antigua and Barbuda        63.4000
# 8            Australia        83.0000
# 9              Austria        80.6188

# %%
stats['Row No.'] = [i+1 for i in range(len(stats))]  # Adding a new column with row numbers
df = stats  # Display the first few rows to see the new column
df
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        africa         ABW     10.244           78.9          High income
# 1        africa         AFG     35.253            5.9           Low income
# 2        africa         AGO     45.985           19.1  Upper middle income
# 3        africa         ALB     12.877           57.2  Upper middle income
# 4        africa         ARE     11.044           88.0          High income
# ..          ...         ...        ...            ...                  ...
# 190      africa         YEM     32.947           20.0  Lower middle income
# 191      africa         ZAF     20.850           46.5  Upper middle income
# 192      africa         COD     42.394            2.2           Low income
# 193      africa         ZMB     40.471           15.4  Lower middle income
# 194      africa         ZWE     35.715           18.5           Low income
#
#      Row No.
# 0          1
# 1          2
# 2          3
# ...

# %%
#renaming specific columns
stats = stats.drop(columns=['xyz'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 2
#       1 #renaming specific columns
# ----> 2 stats = stats.drop(columns=['xyz'])
#
# File c:\Users\SURIYA KUMAR\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
stats.drop(0) # Drop the first row
# assigning the result back to itself will remove the row permanently
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Row No.
# 1             Low income        2
# 2    Upper middle income        3
# 3    Upper middle income        4
# 4            High income        5
# ...

# %%
#Filtering data
Filter = stats.InternetUsers < 2  # Create a filter for Internet Users less than 2
stats[Filter]  # Apply the filter to the DataFrame
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      Row No.
# 11        12
# 52        53
# 55        56
# 64        65
# 117      118
# 127      128
# 154      155
# 156      157
# 172      173

# %%
stats[["CountryName"]] = "Burundi"  # Set all values in the 'CountryName' column to "Burundi"
stats
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0       Burundi         ABW     10.244           78.9          High income
# 1       Burundi         AFG     35.253            5.9           Low income
# 2       Burundi         AGO     45.985           19.1  Upper middle income
# 3       Burundi         ALB     12.877           57.2  Upper middle income
# 4       Burundi         ARE     11.044           88.0          High income
# ..          ...         ...        ...            ...                  ...
# 190     Burundi         YEM     32.947           20.0  Lower middle income
# 191     Burundi         ZAF     20.850           46.5  Upper middle income
# 192     Burundi         COD     42.394            2.2           Low income
# 193     Burundi         ZMB     40.471           15.4  Lower middle income
# 194     Burundi         ZWE     35.715           18.5           Low income
#
#      Row No.
# 0          1
# 1          2
# 2          3
# ...

# %%
stats.CountryName = "africa"
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        africa         ABW     10.244           78.9          High income
# 1        africa         AFG     35.253            5.9           Low income
# 2        africa         AGO     45.985           19.1  Upper middle income
# 3        africa         ALB     12.877           57.2  Upper middle income
# 4        africa         ARE     11.044           88.0          High income
# ..          ...         ...        ...            ...                  ...
# 190      africa         YEM     32.947           20.0  Lower middle income
# 191      africa         ZAF     20.850           46.5  Upper middle income
# 192      africa         COD     42.394            2.2           Low income
# 193      africa         ZMB     40.471           15.4  Lower middle income
# 194      africa         ZWE     35.715           18.5           Low income
#
#      Row No.
# 0          1
# 1          2
# 2          3
# ...

# %%
#Filtering data with multiple conditions
Filter = (stats.InternetUsers < 2) & (stats.BirthRate > 30)  # Multiple conditions / 'and' operator wont work
stats[Filter]  # Apply the filter to the DataFrame
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 11       africa         BDI     44.151            1.3           Low income
# 52       africa         ERI     34.800            0.9           Low income
# 55       africa         ETH     32.925            1.9           Low income
# 64       africa         GIN     37.337            1.6           Low income
# 127      africa         NER     49.661            1.7           Low income
# 154      africa         SLE     36.729            1.7           Low income
# 156      africa         SOM     43.891            1.5           Low income
# 172      africa         TLS     35.755            1.1  Lower middle income
#
#      Row No.
# 11        12
# 52        53
# 55        56
# 64        65
# 127      128
# 154      155
# 156      157
# 172      173

# %%
stats
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        africa         ABW     10.244           78.9          High income
# 1        africa         AFG     35.253            5.9           Low income
# 2        africa         AGO     45.985           19.1  Upper middle income
# 3        africa         ALB     12.877           57.2  Upper middle income
# 4        africa         ARE     11.044           88.0          High income
# ..          ...         ...        ...            ...                  ...
# 190      africa         YEM     32.947           20.0  Lower middle income
# 191      africa         ZAF     20.850           46.5  Upper middle income
# 192      africa         COD     42.394            2.2           Low income
# 193      africa         ZMB     40.471           15.4  Lower middle income
# 194      africa         ZWE     35.715           18.5           Low income
#
#      Row No.
# 0          1
# 1          2
# 2          3
# ...

# %% [markdown]
# ---

# %%
stats = pd.read_csv("C:\\Users\\SURIYA KUMAR\\OneDrive\\ML\\Python A-Z\\Section 5_ Data Frames\\S5-Demographic-Data.csv")
stats["rownumber"] = [i+1 for i in range(len(stats))]  # Adding a new column with row numbers
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup', 'RowNumber']  # Renaming columns
stats.head()  # Display the first few rows to see the new column
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  RowNumber
# 0          High income          1
# 1           Low income          2
# 2  Upper middle income          3
# 3  Upper middle income          4
# 4          High income          5

# %%
stats.IncomeGroup == "High income"  # Filter for 'High income: OECD' in the 'IncomeGroup' column
stats[stats.IncomeGroup == "High income"]  # Apply the filter to the DataFrame
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
#      RowNumber
# 0            1
# ...

# %%
stats.IncomeGroup.unique()  # Get unique values in the 'IncomeGroup' column
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# Filter for rows where 'CountryName' is "Malta" and "India"
stats[(stats.CountryName == "Malta") | (stats.CountryName == "India")]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 80        India         IND     20.291        15.1000  Lower middle income
# 116       Malta         MLT      9.500        68.9138          High income
#
#      RowNumber
# 80          81
# 116        117

# %%
# Filter for rows with multiple numbers in 'RowNumber'
stats[(stats.index <= 5) | (stats.RowNumber >= 190)]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 189                 Samoa         WSM     26.172           15.3
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  RowNumber
# 0            High income          1
# 1             Low income          2
# ...

# %%
#Accessing specific rows and columns
stats.iloc[0:5, 0:2]  # Access the first 5 rows and first 2 columns
# Out:
#             CountryName CountryCode
# 0                 Aruba         ABW
# 1           Afghanistan         AFG
# 2                Angola         AGO
# 3               Albania         ALB
# 4  United Arab Emirates         ARE

# %%
#Accessing specific elements
stats.iloc[1, 2]  # Access the element at row 0, column 0 (first row, first column)
# Out:
# np.float64(35.253)

# %%
#.iat() is used for accessing a single value for a row/column label pair
stats.iat[1, 2]  # Access the element at row 1, column 2 (second row, third column)
# Out:
# np.float64(35.253)

# %%
#.at() is used for label-based indexing
stats.at[1, 'CountryName']  # Access the element at row 1, column 2 (second row, third column)
# Out:
# 'Afghanistan'

# %% [markdown]
# ---

# %% [markdown]
# # Intro to SeaBorn visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10, 5  # Set default figure size

# %%
#distribution plot
sns.displot(stats['InternetUsers'], bins = 30)  # Distribution plot for 'InternetUsers'

# %%
#distribution plot
sns.displot(stats['BirthRate'], bins = 30)  # Distribution plot for 'BirthRate'

# %%
#boxplot
sns.boxplot(data=stats, x='IncomeGroup', y='InternetUsers')  # Boxplot for 'InternetUsers' by 'IncomeGroup'
# Out:
# <Axes: xlabel='IncomeGroup', ylabel='InternetUsers'>

# %%
# Scatter plot with regression line
sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', 
           hue='IncomeGroup', # Color by 'IncomeGroup'
           fit_reg=False, # Disable regression line
           scatter_kws={"s":100})  #unwrapped from matplotlib
